# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.metrics import (
    r2_score, mean_absolute_error, mean_squared_error
)

from xgboost import XGBRegressor

import joblib


df = pd.read_csv("../data/clean/tiempos_final.csv")

df.head()
# Out:
#               zona                              atraccion  tiempo_espera  \
# 0  Cartoon Village                         A Toda Máquina              5
# 1  Cartoon Village  Academia de Pilotos Baby Looney Tunes              0
# 2  Cartoon Village                       Cartoon Carousel              5
# 3  Cartoon Village                     Convoy de Camiones              0
# 4  Cartoon Village                   Correcaminos Bip Bip             15
#
#   abierta       ultima_actualizacion       fecha      hora dia_semana   mes  \
# 0    True  2025-10-30 15:25:08+00:00  2025-10-30  16:26:19   Thursday  10.0
# 1   False  2025-10-30 15:25:08+00:00  2025-10-30  16:26:19   Thursday  10.0
# 2    True  2025-10-30 15:25:08+00:00  2025-10-30  16:26:19   Thursday  10.0
# 3   False  2025-10-30 15:25:08+00:00  2025-10-30  16:26:19   Thursday  10.0
# 4    True  2025-10-30 15:25:08+00:00  2025-10-30  16:26:19   Thursday  10.0
#
#    fin_de_semana  temperatura  humedad  sensacion_termica  codigo_clima  \
# 0          False         17.2     71.0               16.5           2.0
# 1          False         17.2     71.0               16.5           2.0
# 2          False         17.2     71.0               16.5           2.0
# 3          False         17.2     71.0               16.5           2.0
# 4          False         17.2     71.0               16.5           2.0
#
#   temporada
# 0      baja
# 1      baja
# 2      baja
# 3      baja
# 4      baja

# %%
df.sample(5)
# Out:
#                        zona                         atraccion tiempo_espera  \
# 1251  DC Super Heroes World    Superman La Atracción de Acero            20
# 580         Cartoon Village   Tom & Jerry Picnic en el Parque            10
# 787      Old West Territory                   Coaster Express            15
# 414   DC Super Heroes World         Batman Gotham City Escape            40
# 215         Cartoon Village  Wile E. Coyote Zona de Explosión             0
#
#      abierta       ultima_actualizacion       fecha      hora dia_semana  \
# 1251    True  2025-10-22 11:35:13+00:00  2025-10-22     11:35  Miércoles
# 580     True  2025-11-08 13:25:09+00:00  2025-11-08  14:26:38   Saturday
# 787      NaN  2025-11-08 15:45:11+00:00  2025-11-08     16:47   Saturday
# 414     True  2025-11-08 11:45:10+00:00  2025-11-08     12:46   Saturday
# 215    False  2025-11-08 11:20:09+00:00  2025-11-08  12:22:28   Saturday
#
#        mes fin_de_semana temperatura humedad sensacion_termica codigo_clima  \
# 1251    10         False        18.8      68              17.3            2
# 580   11.0          True        14.8    44.0              12.3          2.0
# 787   11.0          True        15.4    39.0              12.5          1.0
# 414   11.0          True        13.4    50.0              10.8          2.0
# 215   11.0          True        13.4    50.0              10.8          2.0
#
#      temporada
# 1251      alta
# 580       baja
# 787       baja
# 414       baja
# 215       baja

# %%
print(df['fecha'].unique())
# Out:
# ['2025-10-30' '2025-11-08' '2025-11-15' 'fecha' '2025-10-16' '2025-10-17'
#  '2025-10-18' '2025-10-22']

# %%
df['fecha'] = pd.to_datetime(df['fecha'])
df['dia_semana_num'] = df['fecha'].dt.weekday
df['mes'] = df['fecha'].dt.month

# %%
df.drop(columns=["dia_semana"])
# Out:
#                      zona                              atraccion  \
# 0         Cartoon Village                         A Toda Máquina
# 1         Cartoon Village  Academia de Pilotos Baby Looney Tunes
# 2         Cartoon Village                       Cartoon Carousel
# 3         Cartoon Village                     Convoy de Camiones
# 4         Cartoon Village                   Correcaminos Bip Bip
# ...                   ...                                    ...
# 1425  Movie World Studios                              Cine Tour
# 1426  Movie World Studios                        Hotel Embrujado
# 1427  Movie World Studios                             Stunt Fall
# 1428   Old West Territory                        Coaster Express
# 1429   Old West Territory                  Los Carros de la Mina
#
#       tiempo_espera abierta       ultima_actualizacion      fecha      hora  \
# 0                 5    True  2025-10-30 15:25:08+00:00 2025-10-30  16:26:19
# 1                 0   False  2025-10-30 15:25:08+00:00 2025-10-30  16:26:19
# 2                 5    True  2025-10-30 15:25:08+00:00 2025-10-30  16:26:19
# 3                 0   False  2025-10-30 15:25:08+00:00 2025-10-30  16:26:19
# 4                15    True  2025-10-30 15:25:08+00:00 2025-10-30  16:26:19
# ...             ...     ...                        ...        ...       ...
# 1425              5    True  2025-10-22 14:05:09+00:00 2025-10-22     14:05
# 1426              5    True  2025-10-22 14:05:09+00:00 2025-10-22     14:05
# 1427             10    True  2025-10-22 14:05:09+00:00 2025-10-22     14:05
# 1428              5    True  2025-10-22 14:05:09+00:00 2025-10-22     14:05
# 1429              5    True  2025-10-22 14:05:09+00:00 2025-10-22     14:05
#
#       mes  fin_de_semana  temperatura  humedad  sensacion_termica  \
# 0      10          False         17.2     71.0               16.5
# 1      10          False         17.2     71.0               16.5
# 2      10          False         17.2     71.0               16.5
# 3      10          False         17.2     71.0               16.5
# 4      10          False         17.2     71.0               16.5
# ...   ...            ...          ...      ...                ...
# 1425   10          False         21.7     51.0               19.2
# 1426   10          False         21.7     51.0               19.2
# 1427   10          False         21.7     51.0               19.2
# 1428   10          False         21.7     51.0               19.2
# 1429   10          False         21.7     51.0               19.2
#
#       codigo_clima temporada  dia_semana_num
# 0              2.0      baja               3
# 1              2.0      baja               3
# 2              2.0      baja               3
# 3              2.0      baja               3
# 4              2.0      baja               3
# ...            ...       ...             ...
# 1425           2.0      alta               2
# 1426           2.0      alta               2
# 1427           2.0      alta               2
# 1428           2.0      alta               2
# 1429           2.0      alta               2
#
# [1430 rows x 15 columns]

# %%
# Out:
#           zona            atraccion  tiempo_espera abierta  \
# 506  Halloween  [HSN] IT Experience              0   False
#
#           ultima_actualizacion      fecha   hora dia_semana  mes  \
# 506  2025-11-08 11:40:09+00:00 2025-11-08  12:42   Saturday   11
#
#      fin_de_semana  temperatura  humedad  sensacion_termica  codigo_clima  \
# 506           True         13.4     50.0               10.8           2.0
#
#     temporada  dia_semana_num
# 506      baja               5

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092 entries, 0 to 1091
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   zona                  1092 non-null   object
#  1   atraccion             1092 non-null   object
#  2   tiempo_espera         1092 non-null   int64
#  3   abierta               846 non-null    object
#  4   ultima_actualizacion  1092 non-null   object
#  5   fecha                 1092 non-null   datetime64[ns]
#  6   hora                  1092 non-null   object
#  7   dia_semana            1092 non-null   object
#  8   mes                   1092 non-null   int32
#  9   fin_de_semana         1092 non-null   bool
#  10  temperatura           1092 non-null   float64
#  11  humedad               1092 non-null   float64
#  12  sensacion_termica     1092 non-null   float64
#  13  codigo_clima          1092 non-null   float64
#  14  temporada             1092 non-null   object
#  15  dia_semana_num        1092 non-null   int32
# dtypes: bool(1), datetime64[ns](1), float64(4), int32(2), int64(1), object(7)
# memory usage: 120.6+ KB

# %%
df["hora"] = pd.to_datetime(df["hora"])
df["hora_num"] = df["hora"].dt.hour
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14556\2981074928.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["hora"] = pd.to_datetime(df["hora"])

# %%
df = df.drop(columns=["hora"])

# %%
df = df.drop(columns=["ultima_actualizacion", "fecha"])

# %%
df = df.drop(columns=["abierta"])

# %%
df.sample(5)
# Out:
#                       zona                   atraccion  tiempo_espera  \
# 139           Warner Beach               IT Experience              5
# 301  DC Super Heroes World      La Venganza del Enigma              5
# 45            Warner Beach               IT Experience              5
# 641  DC Super Heroes World  The Joker Coches de Choque             10
# 104        Cartoon Village   Looney Tunes Correo Aéreo              5
#
#     dia_semana  mes  fin_de_semana  temperatura  humedad  sensacion_termica  \
# 139   Thursday   10          False         17.2     71.0               16.5
# 301   Saturday   11           True         13.4     50.0               10.8
# 45    Thursday   10          False         17.2     71.0               16.5
# 641   Saturday   11           True         14.3     46.0               11.9
# 104   Thursday   10          False         17.2     71.0               16.5
#
#      codigo_clima temporada  dia_semana_num  hora_num
# 139           2.0      baja               3        16
# 301           2.0      baja               5        12
# 45            2.0      baja               3        16
# 641           3.0      baja               5        13
# 104           2.0      baja               3        16

# %%
df["fin_de_semana"] = df["fin_de_semana"].astype(int)
df = df.drop(columns=["dia_semana"])

# %%
df.sample(5)
# Out:
#                       zona                   atraccion  tiempo_espera  mes  \
# 698    Movie World Studios             Hotel Embrujado              5   11
# 255  DC Super Heroes World  The Joker Coches de Choque              5   11
# 227     Old West Territory          Cataratas Salvajes              0   11
# 539        Cartoon Village   La Aventura de Scooby-Doo             30   11
# 586  DC Super Heroes World           Shadows of Arkham             25   11
#
#      fin_de_semana  temperatura  humedad  sensacion_termica  codigo_clima  \
# 698              1         15.2     41.0               12.4           2.0
# 255              1         13.4     50.0               10.8           2.0
# 227              1         13.4     50.0               10.8           2.0
# 539              1         14.8     44.0               12.3           2.0
# 586              1         14.8     44.0               12.3           2.0
#
#     temporada  dia_semana_num  hora_num
# 698      baja               5        15
# 255      baja               5        12
# 227      baja               5        12
# 539      baja               5        14
# 586      baja               5        14

# %%
df["temporada"] = df["temporada"].map({"baja": 0, "media":1, "alta": 2})

# %%
df.sample(5)
# Out:
#                        zona                  atraccion  tiempo_espera  mes  \
# 1265  DC Super Heroes World          Shadows of Arkham             10   10
# 820     Movie World Studios                 Stunt Fall              5   11
# 946         Cartoon Village     La Captura de Gossamer              5   10
# 704         Cartoon Village  La Aventura de Scooby-Doo             15   11
# 1224        Cartoon Village     La Captura de Gossamer              5   10
#
#       fin_de_semana  temperatura  humedad  sensacion_termica  codigo_clima  \
# 1265              0         18.8     68.0               17.3           2.0
# 820               1         13.1     83.0               11.9          61.0
# 946               0         22.6     44.0               22.2           1.0
# 704               1         15.2     41.0               12.4           2.0
# 1224              0         18.8     68.0               17.3           2.0
#
#       temporada  dia_semana_num  hora_num
# 1265          2               2        11
# 820           0               5        15
# 946           2               4        13
# 704           0               5        15
# 1224          2               2        11

# %%
print(df.dtypes)
# Out:
# zona                  object
# atraccion             object
# tiempo_espera          int64
# mes                    int32
# fin_de_semana          int64
# temperatura          float64
# humedad              float64
# sensacion_termica    float64
# codigo_clima         float64
# temporada              int64
# dia_semana_num         int32
# hora_num               int32
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(887)

# %%
df[df.duplicated(keep=False)]
# Out:
#                      zona                              atraccion  \
# 0         Cartoon Village                         A Toda Máquina
# 1         Cartoon Village  Academia de Pilotos Baby Looney Tunes
# 2         Cartoon Village                       Cartoon Carousel
# 3         Cartoon Village                     Convoy de Camiones
# 5         Cartoon Village                 Emergencias Pato Lucas
# ...                   ...                                    ...
# 1409  Movie World Studios                              Cine Tour
# 1410  Movie World Studios                        Hotel Embrujado
# 1411  Movie World Studios                             Stunt Fall
# 1412   Old West Territory                        Coaster Express
# 1413   Old West Territory                  Los Carros de la Mina
#
#       tiempo_espera  mes  fin_de_semana  temperatura  humedad  \
# 0                 5   10              0         17.2     71.0
# 1                 0   10              0         17.2     71.0
# 2                 5   10              0         17.2     71.0
# 3                 0   10              0         17.2     71.0
# 5                 0   10              0         17.2     71.0
# ...             ...  ...            ...          ...      ...
# 1409              5   10              0         20.9     58.0
# 1410              5   10              0         20.9     58.0
# 1411              5   10              0         20.9     58.0
# 1412              5   10              0         20.9     58.0
# 1413              5   10              0         20.9     58.0
#
#       sensacion_termica  codigo_clima  temporada  dia_semana_num  hora_num
# 0                  16.5           2.0          0               3        16
# 1                  16.5           2.0          0               3        16
# 2                  16.5           2.0          0               3        16
# 3                  16.5           2.0          0               3        16
# 5                  16.5           2.0          0               3        16
# ...                 ...           ...        ...             ...       ...
# 1409               19.3           1.0          2               2        13
# 1410               19.3           1.0          2               2        13
# 1411               19.3           1.0          2               2        13
# 1412               19.3           1.0          2               2        13
# 1413               19.3           1.0          2               2        13
#
# [1220 rows x 12 columns]

# %%
# Detectar filas duplicadas considerando todas las columnas
duplicados = df[df.duplicated(keep=False)]

# Mostrar cuántas filas duplicadas hay
print("Número de filas duplicadas:", len(duplicados))

# Si quieres ver exactamente cuáles son las filas duplicadas
print(duplicados)
# Out:
# Número de filas duplicadas: 1220
#                      zona                              atraccion  \
# 0         Cartoon Village                         A Toda Máquina
# 1         Cartoon Village  Academia de Pilotos Baby Looney Tunes
# 2         Cartoon Village                       Cartoon Carousel
# 3         Cartoon Village                     Convoy de Camiones
# 5         Cartoon Village                 Emergencias Pato Lucas
# ...                   ...                                    ...
# 1409  Movie World Studios                              Cine Tour
# 1410  Movie World Studios                        Hotel Embrujado
# 1411  Movie World Studios                             Stunt Fall
# 1412   Old West Territory                        Coaster Express
# 1413   Old West Territory                  Los Carros de la Mina
#
#       tiempo_espera  mes  fin_de_semana  temperatura  humedad  \
# 0                 5   10              0         17.2     71.0
# 1                 0   10              0         17.2     71.0
# 2                 5   10              0         17.2     71.0
# 3                 0   10              0         17.2     71.0
# 5                 0   10              0         17.2     71.0
# ...             ...  ...            ...          ...      ...
# 1409              5   10              0         20.9     58.0
# 1410              5   10              0         20.9     58.0
# 1411              5   10              0         20.9     58.0
# 1412              5   10              0         20.9     58.0
# 1413              5   10              0         20.9     58.0
#
#       sensacion_termica  codigo_clima  temporada  dia_semana_num  hora_num
# 0                  16.5           2.0          0               3        16
# 1                  16.5           2.0          0               3        16
# 2                  16.5           2.0          0               3        16
# 3                  16.5           2.0          0               3        16
# 5                  16.5           2.0          0               3        16
# ...                 ...           ...        ...             ...       ...
# 1409               19.3           1.0          2               2        13
# 1410               19.3           1.0          2               2        13
# 1411               19.3           1.0          2               2        13
# 1412               19.3           1.0          2               2        13
# 1413               19.3           1.0          2               2        13
#
# [1220 rows x 12 columns]

# %%
# Contar cuántas veces se repite cada fila
conteo_filas = df.groupby(list(df.columns)).size().reset_index(name='conteo')

# Filtrar solo las que se repiten más de una vez
filas_repetidas = conteo_filas[conteo_filas['conteo'] > 1]

print(filas_repetidas)
# Out:
#                    zona              atraccion  tiempo_espera  mes  \
# 0       Cartoon Village         A Toda Máquina              5   10
# 3       Cartoon Village         A Toda Máquina              5   10
# 5       Cartoon Village         A Toda Máquina              5   10
# 6       Cartoon Village         A Toda Máquina              5   10
# 7       Cartoon Village         A Toda Máquina              5   10
# ..                  ...                    ...            ...  ...
# 534  Old West Territory  Los Carros de la Mina              5   11
# 535  Old West Territory  Los Carros de la Mina              5   11
# 539  Old West Territory              Río Bravo              0   10
# 541  Old West Territory              Río Bravo              0   11
# 542  Old West Territory              Río Bravo              0   11
#
#      fin_de_semana  temperatura  humedad  sensacion_termica  codigo_clima  \
# 0                0         17.2     71.0               16.5           2.0
# 3                0         18.8     68.0               17.3           2.0
# 5                0         20.2     61.0               18.3           1.0
# 6                0         20.9     58.0               19.3           1.0
# 7                0         22.6     44.0               22.2           1.0
# ..             ...          ...      ...                ...           ...
# 534              1         15.2     41.0               12.4           2.0
# 535              1         15.4     39.0               12.5           1.0
# 539              0         17.2     71.0               16.5           2.0
# 541              1         13.4     50.0               10.8           2.0
# 542              1         14.8     44.0               12.3           2.0
#
#      temporada  dia_semana_num  hora_num  conteo
# 0            0               3        16       3
# 3            2               2        11       4
# 5            2               2        12       4
# 6            2               2        13       4
# 7            2               4        13       2
# ..         ...             ...       ...     ...
# 534          0               5        15       5
# 535          0               5        16       4
# 539          0               3        16       3
# 541          0               5        12       9
# 542          0               5        14       5
#
# [333 rows x 13 columns]

# %%
duplicadas_todas = df[df.duplicated(keep=False)]
print(duplicadas_todas)
# Out:
#                      zona                              atraccion  \
# 0         Cartoon Village                         A Toda Máquina
# 1         Cartoon Village  Academia de Pilotos Baby Looney Tunes
# 2         Cartoon Village                       Cartoon Carousel
# 3         Cartoon Village                     Convoy de Camiones
# 5         Cartoon Village                 Emergencias Pato Lucas
# ...                   ...                                    ...
# 1409  Movie World Studios                              Cine Tour
# 1410  Movie World Studios                        Hotel Embrujado
# 1411  Movie World Studios                             Stunt Fall
# 1412   Old West Territory                        Coaster Express
# 1413   Old West Territory                  Los Carros de la Mina
#
#       tiempo_espera  mes  fin_de_semana  temperatura  humedad  \
# 0                 5   10              0         17.2     71.0
# 1                 0   10              0         17.2     71.0
# 2                 5   10              0         17.2     71.0
# 3                 0   10              0         17.2     71.0
# 5                 0   10              0         17.2     71.0
# ...             ...  ...            ...          ...      ...
# 1409              5   10              0         20.9     58.0
# 1410              5   10              0         20.9     58.0
# 1411              5   10              0         20.9     58.0
# 1412              5   10              0         20.9     58.0
# 1413              5   10              0         20.9     58.0
#
#       sensacion_termica  codigo_clima  temporada  dia_semana_num  hora_num
# 0                  16.5           2.0          0               3        16
# 1                  16.5           2.0          0               3        16
# 2                  16.5           2.0          0               3        16
# 3                  16.5           2.0          0               3        16
# 5                  16.5           2.0          0               3        16
# ...                 ...           ...        ...             ...       ...
# 1409               19.3           1.0          2               2        13
# 1410               19.3           1.0          2               2        13
# 1411               19.3           1.0          2               2        13
# 1412               19.3           1.0          2               2        13
# 1413               19.3           1.0          2               2        13
#
# [1220 rows x 12 columns]

# %%
df[df.duplicated(keep=False)]
# Out:
#                      zona                              atraccion  \
# 0         Cartoon Village                         A Toda Máquina
# 1         Cartoon Village  Academia de Pilotos Baby Looney Tunes
# 2         Cartoon Village                       Cartoon Carousel
# 3         Cartoon Village                     Convoy de Camiones
# 5         Cartoon Village                 Emergencias Pato Lucas
# ...                   ...                                    ...
# 1409  Movie World Studios                              Cine Tour
# 1410  Movie World Studios                        Hotel Embrujado
# 1411  Movie World Studios                             Stunt Fall
# 1412   Old West Territory                        Coaster Express
# 1413   Old West Territory                  Los Carros de la Mina
#
#       tiempo_espera  mes  fin_de_semana  temperatura  humedad  \
# 0                 5   10              0         17.2     71.0
# 1                 0   10              0         17.2     71.0
# 2                 5   10              0         17.2     71.0
# 3                 0   10              0         17.2     71.0
# 5                 0   10              0         17.2     71.0
# ...             ...  ...            ...          ...      ...
# 1409              5   10              0         20.9     58.0
# 1410              5   10              0         20.9     58.0
# 1411              5   10              0         20.9     58.0
# 1412              5   10              0         20.9     58.0
# 1413              5   10              0         20.9     58.0
#
#       sensacion_termica  codigo_clima  temporada  dia_semana_num  hora_num
# 0                  16.5           2.0          0               3        16
# 1                  16.5           2.0          0               3        16
# 2                  16.5           2.0          0               3        16
# 3                  16.5           2.0          0               3        16
# 5                  16.5           2.0          0               3        16
# ...                 ...           ...        ...             ...       ...
# 1409               19.3           1.0          2               2        13
# 1410               19.3           1.0          2               2        13
# 1411               19.3           1.0          2               2        13
# 1412               19.3           1.0          2               2        13
# 1413               19.3           1.0          2               2        13
#
# [1220 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# zona                 0
# atraccion            0
# tiempo_espera        0
# mes                  0
# fin_de_semana        0
# temperatura          0
# humedad              0
# sensacion_termica    0
# codigo_clima         0
# temporada            0
# dia_semana_num       0
# hora_num             0
# dtype: int64

# %%
df.sample(5)
# Out:
#                        zona                       atraccion  tiempo_espera  \
# 1231  DC Super Heroes World  Superman La Atracción de Acero             20
# 681     Movie World Studios                      Stunt Fall              5
# 625     Movie World Studios                      Stunt Fall              5
# 659   DC Super Heroes World  Superman La Atracción de Acero             30
# 1011     Old West Territory           Los Carros de la Mina              5
#
#       mes  fin_de_semana  temperatura  humedad  sensacion_termica  \
# 1231   10              0         18.8     68.0               17.3
# 681    11              1         15.2     41.0               12.4
# 625    11              1         14.8     44.0               12.3
# 659    11              1         15.2     41.0               12.4
# 1011   10              0         23.8     40.0               23.4
#
#       codigo_clima  temporada  dia_semana_num  hora_num
# 1231           2.0          2               2        11
# 681            2.0          0               5        15
# 625            2.0          0               5        14
# 659            2.0          0               5        15
# 1011           1.0          2               4        14

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# Tus columnas categóricas
categorical_features = ['zona', 'atraccion']

# Inicializar OneHotEncoder
ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# Ajustar y transformar
ohe_array = ohe.fit_transform(df[categorical_features])

# Obtener nombres de las nuevas columnas
ohe_columns = ohe.get_feature_names_out(categorical_features)

# Crear DataFrame con las columnas codificadas
df_ohe = pd.DataFrame(ohe_array, columns=ohe_columns, index=df.index)

# Concatenar con el DataFrame original (opcional: puedes quitar las columnas originales)
df_final = pd.concat([df.drop(columns=categorical_features), df_ohe], axis=1)

# Hacer un sample de 10 filas para ver

# %%
df_final.sample()
# Out:
#      tiempo_espera  mes  fin_de_semana  temperatura  humedad  \
# 114              0   10              0         17.2     72.0
#
#      sensacion_termica  codigo_clima  temporada  dia_semana_num  hora_num  \
# 114               16.6           2.0          0               3        17
#
#      ...  atraccion_Piolín y Silvestre Paseo en Autobús  \
# 114  ...                                            0.0
#
#      atraccion_Rápidos ACME  atraccion_Río Bravo  \
# 114                     0.0                  0.0
#
#      atraccion_Scooby-Doo's Tea Party Mistery  atraccion_Shadows of Arkham  \
# 114                                       1.0                          0.0
#
#      atraccion_Stunt Fall  atraccion_Superman La Atracción de Acero  \
# 114                   0.0                                       0.0
#
#      atraccion_The Joker Coches de Choque  \
# 114                                   0.0
#
#      atraccion_Tom & Jerry Picnic en el Parque  \
# 114                                        0.0
#
#      atraccion_Wile E. Coyote Zona de Explosión
# 114                                         0.0
#
# [1 rows x 47 columns]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
df.sample(5)
